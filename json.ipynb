# %%
import pandas as pd

# %%
pd.read_json('r-train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
# pd.read_json('#url')

# %% [markdown]
# # Working with SQL

# %%
import psycopg2

conn_obj =  psycopg2.connect(
    host="localhost",
    database="postgres",
    user="postgres",
    password="postgres")

pd.read_sql_query("Select * from title", conn_obj)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[27], line 3
#       1 import psycopg2
# ----> 3 conn_obj =  psycopg2.connect(
#       4     host="localhost",
#       5     database="postgres",
#       6     user="postgres",
#       7     password="postgres")
#       9 pd.read_sql_query("Select * from title", conn_obj)
#
# File ~/anaconda3/envs/notebook/lib/python3.11/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: FATAL:  password authentication failed for user "postgres"

# %% [markdown]
# ## API: Application Programming Interface

# %%
import requests

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIzNDRmYmIzMTkzNjI5MjA3MmE0YjMxNWE5ODU3MzdmZCIsInN1YiI6IjY1ODRiMTk1OTljOTY0NjA1MGVmNjgzMSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ohabRaa9tZ82x1To1UVOZ8ROa0NWL8jmtC6yIuLZZXw"
}
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/bmlkLCjrIWnnZzdAQ4uNPG9JFdj.jpg","genre_ids":[35,10751,14],"id":787699,"original_language":"en","original_title":"Wonka","overview":"Willy Wonka – chock-full of ideas and determined to change the world one delectable bite at a time – is proof that the best things in life begin with a dream, and if you’re lucky enough to meet Willy Wonka, anything is possible.","popularity":1081.396,"poster_path":"/qhb1qOilapbapxWQn9jtRCMwXJF.jpg","release_date":"2023-12-06","title":"Wonka","video":false,"vote_average":7.3,"vote_count":386},{"adult":false,"backdrop_path":"/jXJxMcVoEuXzym3vFnjqDW4ifo6.jpg","genre_ids":[28,12,14],"id":572802,"original_language":"en","original_title":"Aquaman and the Lost Kingdom","overview":"Black Manta, still driven by the need to avenge his father's death and wielding the power of the mythic Black Trident, will stop at nothing to take Aquaman down once and for all. To defeat him, Aquaman must turn to his imprisoned
# ...

# %%
df = pd.DataFrame()
for i in range(1, 100):
    url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=" + str(i)
    response = requests.get(url, headers=headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
    df = pd.concat([df, temp_df], axis=0, ignore_index=True)

# %%
df
# Out:
#          id                        title  \
# 0       238                The Godfather
# 1       278     The Shawshank Redemption
# 2       240        The Godfather Part II
# 3       424             Schindler's List
# 4     19404  Dilwale Dulhania Le Jayenge
# ...     ...                          ...
# 9012  12142            Alone in the Dark
# 9013   5491            Battlefield Earth
# 9014  11059            House of the Dead
# 9015  14164         Dragonball Evolution
# 9016  40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# ...
